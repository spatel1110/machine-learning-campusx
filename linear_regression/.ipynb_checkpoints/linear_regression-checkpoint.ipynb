# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('./../data/IPL Ball-by-Ball 2008-2020.csv')

# %%
df
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# ...

# %%
runs = df[df['batsman'] == 'V Kohli']

# %%
total_run = runs.groupby('id').sum('batsman_runs')
total_ball = runs.groupby('id').count()

# %%
plt.scatter(total_ball['ball'],total_run['batsman_runs'])
plt.xlabel('Total ball in each match')
plt.ylabel('Total runs in each match')
plt.show()

# %%
X = total_ball.iloc[:,2:3]
Y = total_ball.iloc[:,6:7]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, Y, test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train.values,y_train.values)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# array([[16.]])

# %%
lr.predict(X_train.values)
# Out:
# array([[33.],
#        [ 5.],
#        [12.],
#        [31.],
#        [ 8.],
#        [18.],
#        [23.],
#        [49.],
#        [16.],
#        [17.],
#        [24.],
#        [42.],
#        [45.],
#        [28.],
#        [11.],
#        [46.],
#        [15.],
#        [30.],
#        [18.],
#        [31.],
#        [35.],
#        [ 9.],
#        [51.],
#        [14.],
#        [11.],
#        [43.],
#        [42.],
#        [ 1.],
#        [ 9.],
#        [36.],
#        [34.],
#        [44.],
#        [ 1.],
#        [24.],
#        [26.],
#        [53.],
#        [42.],
#        [ 5.],
#        [12.],
#        [62.],
#        [20.],
#        [15.],
#        [24.],
#        [26.],
#        [31.],
#        [48.],
#        [35.],
#        [24.],
#        [33.],
#        [12.],
#        [ 4.],
#        [17.],
#        [ 8.],
#        [ 2.],
#        [51.],
#        [11.],
#        [57.],
#        [35.],
#        [14.],
#        [24.],
#        [ 1.],
#        [28.],
# ...

# %%
plt.scatter(total_ball['ball'],total_run['batsman_runs'])
plt.plot(X_train,lr.predict(X_train.values),color='red')
plt.xlabel('Ball')
plt.ylabel('Runs')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred = lr.predict(X_test.values)

# %%
X_test.values
# Out:
# array([[16],
#        [43],
#        [32],
#        [ 8],
#        [ 9],
#        [17],
#        [27],
#        [ 2],
#        [18],
#        [39],
#        [13],
#        [ 5],
#        [23],
#        [12],
#        [ 7],
#        [28],
#        [55],
#        [ 9],
#        [51],
#        [ 5],
#        [51],
#        [33],
#        [ 7],
#        [14],
#        [ 6],
#        [29],
#        [24],
#        [ 8],
#        [64],
#        [17],
#        [15],
#        [16],
#        [ 8],
#        [58],
#        [38],
#        [32],
#        [54]])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 3.780759489264047e-15

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 2.102740723714116e-29

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 4.585565094635683e-15

# %%
print("MSE",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# MSE 1.0
